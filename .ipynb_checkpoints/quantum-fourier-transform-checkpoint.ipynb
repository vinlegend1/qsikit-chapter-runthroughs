# %%
import numpy as np
from numpy import pi
# importing Qiskit
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.providers.ibmq import least_busy
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram, plot_bloch_multivector
# %config InlineBackend.figure_format = 'svg' # Makes the images look nice

# %%
qc = QuantumCircuit(3)

# %%
qc.h(2)
qc.draw()
# Out:
#
# q_0: ─────
#
# q_1: ─────
#      ┌───┐
# q_2: ┤ H ├
#      └───┘

# %%
qc.cu1(pi/2, 1, 2) # CROT from qubit 1 to qubit 2
qc.draw()
# Out:
# <ipython-input-28-eb34571e110a>:1: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   qc.cu1(pi/2, 1, 2) # CROT from qubit 1 to qubit 2
#
# q_0: ───────────
#
# q_1: ──────■────
#      ┌───┐ │π/2
# q_2: ┤ H ├─■────
#      └───┘

# %%
qc.cu1(pi/4, 0, 2) # CROT from qubit 2 to qubit 0
qc.draw()
# Out:
# <ipython-input-29-84123d85002c>:1: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   qc.cu1(pi/4, 0, 2) # CROT from qubit 2 to qubit 0
#
# q_0: ────────────■────
#                  │
# q_1: ──────■─────┼────
#      ┌───┐ │π/2  │π/4
# q_2: ┤ H ├─■─────■────
#      └───┘

# %%
qc.h(1)
qc.cu1(pi/2, 0, 1) # CROT from qubit 0 to qubit 1
qc.h(0)
qc.draw()
# Out:
# <ipython-input-30-7a2db73cf446>:2: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   qc.cu1(pi/2, 0, 1) # CROT from qubit 0 to qubit 1
#                                  ┌───┐
# q_0: ────────────■──────────■────┤ H ├
#                  │    ┌───┐ │π/2 └───┘
# q_1: ──────■─────┼────┤ H ├─■─────────
#      ┌───┐ │π/2  │π/4 └───┘
# q_2: ┤ H ├─■─────■────────────────────
#      └───┘

# %%
qc.swap(0,2)
qc.draw()
# Out:
#                                  ┌───┐
# q_0: ────────────■──────────■────┤ H ├─X─
#                  │    ┌───┐ │π/2 └───┘ │
# q_1: ──────■─────┼────┤ H ├─■──────────┼─
#      ┌───┐ │π/2  │π/4 └───┘            │
# q_2: ┤ H ├─■─────■─────────────────────X─
#      └───┘

# %%
def qft_rotations(circuit, n):
    if n == 0: # Exit function if circuit is empty
        return circuit
    n -= 1 # Indexes start from 0
    circuit.h(n) # Apply the H-gate to the most significant qubit
    for qubit in range(n):
        # For each less significant qubit, we need to do a
        # smaller-angled controlled rotation: 
        circuit.cu1(pi/2**(n-qubit), qubit, n)

# %%
qc = QuantumCircuit(4)
qft_rotations(qc,4)
qc.draw()
# Out:
# <ipython-input-32-7abefe38557f>:9: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   circuit.cu1(pi/2**(n-qubit), qubit, n)
#
# q_0: ──────■────────────────
#            │
# q_1: ──────┼─────■──────────
#            │     │
# q_2: ──────┼─────┼─────■────
#      ┌───┐ │π/8  │π/4  │π/2
# q_3: ┤ H ├─■─────■─────■────
#      └───┘

# %%
def qft_rotations(circuit, n):
    """Performs qft on the first n qubits in circuit (without swaps)"""
    if n == 0:
        return circuit
    n -= 1
    circuit.h(n)
    for qubit in range(n):
        circuit.cu1(pi/2**(n-qubit), qubit, n)
    # At the end of our function, we call the same function again on
    # the next qubits (we reduced n by one earlier in the function)
    qft_rotations(circuit, n)

# Let's see how it looks:
qc = QuantumCircuit(4)
qft_rotations(qc,4)
qc.draw()
# Out:
# <ipython-input-34-2ef4e92dff5b>:8: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   circuit.cu1(pi/2**(n-qubit), qubit, n)
#                                                         ┌───┐
# q_0: ──────■──────────────────────■────────────────■────┤ H ├
#            │                      │          ┌───┐ │π/2 └───┘
# q_1: ──────┼─────■────────────────┼─────■────┤ H ├─■─────────
#            │     │          ┌───┐ │π/4  │π/2 └───┘
# q_2: ──────┼─────┼─────■────┤ H ├─■─────■────────────────────
#      ┌───┐ │π/8  │π/4  │π/2 └───┘
# q_3: ┤ H ├─■─────■─────■─────────────────────────────────────
#      └───┘

# %%
def swap_registers(circuit, n):
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)
    return circuit

def qft(circuit, n):
    """QFT on the first n qubits in circuit"""
    qft_rotations(circuit, n)
    swap_registers(circuit, n)
    return circuit

# Let's see how it looks:
qc = QuantumCircuit(4)
qft(qc,4)
qc.draw()
# Out:
# <ipython-input-34-2ef4e92dff5b>:8: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   circuit.cu1(pi/2**(n-qubit), qubit, n)
#                                                         ┌───┐
# q_0: ──────■──────────────────────■────────────────■────┤ H ├─X─
#            │                      │          ┌───┐ │π/2 └───┘ │
# q_1: ──────┼─────■────────────────┼─────■────┤ H ├─■──────X───┼─
#            │     │          ┌───┐ │π/4  │π/2 └───┘        │   │
# q_2: ──────┼─────┼─────■────┤ H ├─■─────■─────────────────X───┼─
#      ┌───┐ │π/8  │π/4  │π/2 └───┘                             │
# q_3: ┤ H ├─■─────■─────■──────────────────────────────────────X─
#      └───┘

# %%
backend = Aer.get_backend("statevector_simulator")
statevector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
qc = QuantumCircuit(3)

# Encode the state 5
qc.x(0)
qc.x(2)
# %config InlineBackend.figure_format = 'svg' # Makes the images fit
qc.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘

# %%
qft(qc,3)
qc.draw()
# Out:
# <ipython-input-34-2ef4e92dff5b>:8: DeprecationWarning: The QuantumCircuit.cu1 method is deprecated as of 0.16.0. It will be removed no earlier than 3 months after the release date. You should use the QuantumCircuit.cp method instead, which acts identically.
#   circuit.cu1(pi/2**(n-qubit), qubit, n)
#      ┌───┐                            ┌───┐
# q_0: ┤ X ├──────■────────────────■────┤ H ├─X─
#      └───┘      │          ┌───┐ │π/2 └───┘ │
# q_1: ───────────┼─────■────┤ H ├─■──────────┼─
#      ┌───┐┌───┐ │π/4  │π/2 └───┘            │
# q_2: ┤ X ├┤ H ├─■─────■─────────────────────X─
#      └───┘└───┘

# %%
backend = Aer.get_backend("statevector_simulator")
statevector = execute(qc, backend=backend).result().get_statevector()
plot_bloch_multivector(statevector)
